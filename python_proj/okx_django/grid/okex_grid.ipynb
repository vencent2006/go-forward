# %%
import numpy

# %%
instId = "BTC-USDT"
res = get_history_klines(instId)
# Out:
# header:  {'Content-Type': 'application/json', 'x-simulated-trading': '1'}
# domain: https://www.okx.com
# url: /api/v5/market/history-candles?instId=BTC-USDT
# {
#   "code": "0",
#   "msg": "",
#   "data": [
#     [
#       "1684400880000",
#       "27393",
#       "27397.8",
#       "27386",
#       "27386.4",
#       "2349.00311846",
#       "64345983.667380859",
#       "64345983.667380859",
#       "1"
#     ],
#     [
#       "1684400820000",
#       "27379.6",
#       "27392.5",
#       "27377.6",
#       "27392.5",
#       "6348.64725014",
#       "173852626.323454661",
#       "173852626.323454661",
#       "1"
#     ],
#     [
#       "1684400760000",
#       "27390.2",
#       "27397.8",
#       "27378.8",
#       "27380.1",
#       "4224.19668769",
#       "115692474.503355599",
#       "115692474.503355599",
#       "1"
#     ],
#     [
#       "1684400700000",
#       "27377.5",
#       "27391.5",
#       "27377.4",
#       "27391.5",
#       "3802.19064865",
# ...

# %%
res
# Out:
# {'code': '0',
#  'msg': '',
#  'data': [['1684400880000',
#    '27393',
#    '27397.8',
#    '27386',
#    '27386.4',
#    '2349.00311846',
#    '64345983.667380859',
#    '64345983.667380859',
#    '1'],
#   ['1684400820000',
#    '27379.6',
#    '27392.5',
#    '27377.6',
#    '27392.5',
#    '6348.64725014',
#    '173852626.323454661',
#    '173852626.323454661',
#    '1'],
#   ['1684400760000',
#    '27390.2',
#    '27397.8',
#    '27378.8',
#    '27380.1',
#    '4224.19668769',
#    '115692474.503355599',
#    '115692474.503355599',
#    '1'],
#   ['1684400700000',
#    '27377.5',
#    '27391.5',
#    '27377.4',
#    '27391.5',
#    '3802.19064865',
#    '104115775.980127666',
#    '104115775.980127666',
#    '1'],
#   ['1684400640000',
#    '27387.3',
#    '27387.3',
#    '27377.4',
#    '27377.4',
#    '3648.16975313',
#    '99889398.934539787',
#    '99889398.934539787',
#    '1'],
#   ['1684400580000',
#    '27391.9',
#    '27392',
#    '27387.2',
#    '27387.3',
# ...

# %%
data = np.array(res.data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data = np.array(res.data)
#
# NameError: name 'np' is not defined
