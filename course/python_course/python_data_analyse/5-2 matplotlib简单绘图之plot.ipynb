# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a = [1,2,3]
plt.plot(a)

# %%
a = [1,2,3]
b = [4,5,6]

# %%
plt.plot(a,b)

# %%
# %timeit np.arange(10)
# Out:
# 421 ns ± 21.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
plt.plot(a,b,'*')

# %%
plt.plot(a,b,'--')

# %%
plt.plot(a,b,'r--')

# %%
plt.plot(a,b,'b--')

# %%
c = [10,8,6]
d = [1,8,3]

# %%
plt.plot(a,b,c,d)
# Out:
# [<matplotlib.lines.Line2D at 0x1207cb520>,
#  <matplotlib.lines.Line2D at 0x1207cbc70>]

# %%
t = np.arange(0.0, 2.0, 0.1)

# %%
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)

# %%
s
# Out:
# array([ 0.00000000e+00,  3.09016994e-01,  5.87785252e-01,  8.09016994e-01,
#         9.51056516e-01,  1.00000000e+00,  9.51056516e-01,  8.09016994e-01,
#         5.87785252e-01,  3.09016994e-01,  1.22464680e-16, -3.09016994e-01,
#        -5.87785252e-01, -8.09016994e-01, -9.51056516e-01, -1.00000000e+00,
#        -9.51056516e-01, -8.09016994e-01, -5.87785252e-01, -3.09016994e-01])

# %%
s.size
# Out:
# 20

# %%
plt.plot(t, s, 'r--')

# %%
plt.plot(t, s, 'r--', t*2, s, '--')
# Out:
# [<matplotlib.lines.Line2D at 0x1215fc2e0>,
#  <matplotlib.lines.Line2D at 0x1215fc6d0>]

# %%
plt.plot(t, s, 'r--', t*2, s, '--')
plt.xlabel('this is x')
plt.ylabel('this is y')
# Out:
# Text(0, 0.5, 'this is y')

# %%
plt.plot(t, s, 'r--',label='aaaa')
plt.plot(t*2, s, 'b--', label='bbbb')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
